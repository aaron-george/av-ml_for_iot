# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')

# %%
df_train=pd.read_csv("train_aWnotuB.csv",index_col="ID")
df_test= pd.read_csv("test_BdBKkAj_L87Nc3S.csv",index_col="ID")
df_submission=pd.read_csv("sample_submission_KVKNmI7.csv")

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = df_train['Junction'].plot(style='.', figsize=(15,5), color=color_pal[0], title='Vehicle Data')
